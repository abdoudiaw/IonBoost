# %% [markdown]
# ## Fluid simulations of a plasma expansion into a vacuum.
# #### This test case reproduces some of the results of Mora's 2003 PRL paper.

# %%
from os import path
from pandas import read_csv
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
#path to rsflash - added to ensure use of up-to-date build

# %%
# %matplotlib inline

# %%
# data_dir='/home/vagrant/jupyter/StaffScratch/diaw/Ionboost/'
data_dir='/Users/diaw/Ionboost/'
folder ='scripts'

# %%
cols =['x0','xt','v','phi','E','ni','ne','rho','nhot','ncold','nss','difnor','dWhot','SWhot','charge']
fname = path.join(data_dir,folder,'profil.txt')
df=read_csv(fname,comment="#",header=None,sep='\s+',names=cols,index_col=False,skiprows=0)

 # x0test xttest vtest itest E
cols =['x0test', 'xttest', 'vtest', 'itest', 'E']
# fname_ = path.join(data_dir,folder,'profil_test')
df_=read_csv(fname_,comment="#",header=None,sep='\s+',names=cols,index_col=False,skiprows=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-cbc140b017bf> in <module>
#       6 cols =['x0test', 'xttest', 'vtest', 'itest', 'E']
#       7 fname_ = path.join(data_dir,folder,'profil_test')
# ----> 8 df_=read_csv(fname_,comment="#",header=None,sep='\s+',names=cols,index_col=False,skiprows=0)
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/diaw/Ionboost/scripts/profil_test'

# %% [markdown]
# ## Let us now look at the charge separation

# %%
wt=50
with mpl.style.context('classic'):
    mpl.rc('font', size = 18)
    mpl.rcParams['figure.figsize'] = 6,4
    fig,ax1 = plt.subplots(1,1)
    ax1.plot(df['xt']/wt,df['rho'], linewidth=2)
    ax1.set_xlim(-2,10)
    ax1.set_xlabel(r'$x/c_s t$', size=15)
    ax1.set_ylabel(r'$(n_e-Z_in_i)/n_{e0}$', size=15)
#     ax1.grid(alpha=0.3)
    ax1.set_title('Charge separation at time $\omega_{pi}t=50$', fontsize=16)
    ax1.grid(linestyle='dashed', linewidth='0.5')
    plt.tight_layout()

    fig.subplots_adjust(hspace=0.3, wspace=0.4)
    plt.savefig('charge_separation.png', bbox_inches = 'tight')     
    plt.show()

# %% [markdown]
# Note that the ion front stands at  $x/c_st \approx 5.59$

# %% [markdown]
# ## Electric field

# %%
with mpl.style.context('classic'):
    mpl.rc('font', size = 18)
    mpl.rcParams['figure.figsize'] = 6,4
    fig,ax1 = plt.subplots(1,1)
    ax1.plot(df['xt']/wt,df['E'], linewidth=2)
    ax1.set_xlim(-2,10)
    ax1.set_xlabel(r'$x/c_s t$', size=15)
    ax1.set_ylabel(r'$E/E_0$', size=15)
#     ax1.grid(alpha=0.3)
    ax1.set_title('Electric field at time $\omega_{pi}t=50$', fontsize=16)
    ax1.grid(linestyle='dashed', linewidth='0.5')
    plt.tight_layout()

    fig.subplots_adjust(hspace=0.3, wspace=0.4)
    plt.savefig('electric_field.png', bbox_inches = 'tight')     
    plt.show()

# %% [markdown]
# The ion front stands at  $x/c_st \approx 5.59$.
#
# Note that the electric field at the ion front is approximately twice the self-similar field.

# %% [markdown]
# ## Density profiles

# %%
with mpl.style.context('classic'):
    mpl.rc('font', size = 18)
    mpl.rcParams['figure.figsize'] = 6,4
    fig,ax1 = plt.subplots(1,1)
    ax1.plot(df['xt']/wt,df['ne'], label='$n_e$', linewidth=2)
    ax1.plot(df['xt']/wt,df['ni'], label='$n_i$', linewidth=2)
    ax1.set_xlim(-2,10)
    ax1.set_xlabel(r'$x/c_s t$', size=15)
    ax1.set_ylabel(r'$n_e/n_{e0},Z_in_i/n_{e0}$', size=15)
    ax1.set_title('Structure of the ion front at time $\omega_{pi}t=50$', fontsize=16)
    ax1.grid(linestyle='dashed', linewidth='0.5')
    ax1.set_yscale('log')
    ax1.set_ylim(1.e-4,10)
    ax1.legend(loc='best')
    plt.tight_layout()

    plt.savefig('densities_profile.png', bbox_inches = 'tight')     
    plt.show()

# %%
wt=50
with mpl.style.context('classic'):
    mpl.rc('font', size = 18)
    mpl.rcParams['figure.figsize'] = 6,4
    fig,ax1 = plt.subplots(1,1)
    ax1.plot(df['xt']/wt,df['v'], label='bulk',linewidth=2)
    ax1.plot(df_['xttest']/wt,df_['vtest'],label='test', linewidth=2)
    ax1.set_xlim(-2,10)
    ax1.set_xlabel(r'$x/c_s t$', size=15)
    ax1.set_ylabel(r'$(n_e-Z_in_i)/n_{e0}$', size=15)
    ax1.grid(alpha=0.3)
#     ax1.set_title('Charge separation at time $\omega_{pi}t=50$', fontsize=16)
    ax1.grid(linestyle='dashed', linewidth='0.5')
#     ax1.legend()
    plt.tight_layout()

    fig.subplots_adjust(hspace=0.3, wspace=0.4)
#     plt.savefig('charge_separation.png', bbox_inches = 'tight')     
    plt.show()

# %% [markdown]
# ## Energy spectrum

# %%
cols =['vmoy', 'Emoy', 'dndv','dndE']
fname = path.join(data_dir,folder,'spectres.txt')
df=read_csv(fname,comment="#",header=None,sep='\s+',names=cols,index_col=False,skiprows=0)

# %%
df
# Out:
#         vmoy     Emoy       dndv        dndE
# 0        NaN      NaN        NaN         NaN
# 1     0.0760   0.0029  73.490993  966.356724
# 2     0.0787   0.0031  72.045880  915.107323
# 3     0.0815   0.0033  70.673215  867.674711
# 4     0.0842   0.0035  69.368609  823.717757
# ...      ...      ...        ...         ...
# 2339  7.5021  28.1405   0.040559    0.005406
# 2340  7.5025  28.1436   0.040552    0.005405
# 2341  7.5029  28.1466   0.040546    0.005404
# 2342  7.5033  28.1497   0.040539    0.005403
# 2343  7.5037  28.1527   0.040533    0.005402
#
# [2344 rows x 4 columns]

# %%
with mpl.style.context('classic'):
    mpl.rc('font', size = 18)
    mpl.rcParams['figure.figsize'] = 6,4
    fig,ax1 = plt.subplots(1,1)
    ax1.plot(df['Emoy'],df['dndE'], label='$n_e$', linewidth=2)
#     ax1.set_xlim(-2,10)
    ax1.set_xlabel(r'$E$', size=15)
    ax1.set_ylabel(r'$dN/dE}$', size=15)
    ax1.set_title('Energy spectrum per unit surface at time $\omega_{pi}t=50$', fontsize=16)
    ax1.grid(linestyle='dashed', linewidth='0.5')
    ax1.set_yscale('log')
#     ax1.set_ylim(1.e-4,10)
    ax1.legend(loc='best')
    plt.tight_layout()

    plt.savefig('energy_spectrum.png', bbox_inches = 'tight')     
    plt.show()

# %% [markdown]
# Energy is normalized to  $Zk_BT_e$, and the number of ions per unit surface
# and unit energy is normalized to $n_{i0} \lambda_{D0}/Zk_BT_e$.
